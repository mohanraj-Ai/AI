# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_Mul.linear.sav",'rb')) 
result=loaded_model.predict([[1356,56554,89999,1,0]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[48438.33609267]])
