# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset[["Purchased"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
param_grid = {
    'criterion':['gini','entropy'],
    'max_features':['auto','sqrt','log2'],
    'n_estimators':[10,100]
}
grid=GridSearchCV(RandomForestClassifier(),param_grid,refit=True,verbose=3,n_jobs=1,scoring='f1')
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END criterion=gini, max_features=auto, n_estimators=10;, score=nan total time=   0.8s
# [CV 2/5] END criterion=gini, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 1/5] END criterion=gini, max_features=sqrt, n_estimators=10;, score=0.727 total time=   2.5s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 2/5] END criterion=gini, max_features=sqrt, n_estimators=10;, score=0.821 total time=   0.2s
# [CV 3/5] END criterion=gini, max_features=sqrt, n_estimators=10;, score=0.810 total time=   0.1s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5] END criterion=gini, max_features=sqrt, n_estimators=10;, score=0.872 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=sqrt, n_estimators=10;, score=0.833 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 1/5] END criterion=gini, max_features=sqrt, n_estimators=100;, score=0.765 total time=   0.9s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 2/5] END criterion=gini, max_features=sqrt, n_estimators=100;, score=0.842 total time=   0.6s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 3/5] END criterion=gini, max_features=sqrt, n_estimators=100;, score=0.810 total time=   0.6s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5] END criterion=gini, max_features=sqrt, n_estimators=100;, score=0.927 total time=   0.6s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 5/5] END criterion=gini, max_features=sqrt, n_estimators=100;, score=0.947 total time=   0.5s
# [CV 1/5] END criterion=gini, max_features=log2, n_estimators=10;, score=0.727 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=log2, n_estimators=10;, score=0.872 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 3/5] END criterion=gini, max_features=log2, n_estimators=10;, score=0.780 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=log2, n_estimators=10;, score=0.872 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 5/5] END criterion=gini, max_features=log2, n_estimators=10;, score=0.919 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 1/5] END criterion=gini, max_features=log2, n_estimators=100;, score=0.727 total time=   0.6s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 2/5] END criterion=gini, max_features=log2, n_estimators=100;, score=0.842 total time=   0.4s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 3/5] END criterion=gini, max_features=log2, n_estimators=100;, score=0.780 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5] END criterion=gini, max_features=log2, n_estimators=100;, score=0.900 total time=   0.4s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 5/5] END criterion=gini, max_features=log2, n_estimators=100;, score=0.947 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.727 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.811 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.810 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.900 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.923 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 1/5] END criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.800 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 2/5] END criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.872 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 3/5] END criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.810 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5] END criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.900 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 5/5] END criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.923 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_features=log2, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=log2, n_estimators=10;, score=0.757 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=log2, n_estimators=10;, score=0.780 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5] END criterion=entropy, max_features=log2, n_estimators=10;, score=0.842 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=log2, n_estimators=10;, score=0.889 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 1/5] END criterion=entropy, max_features=log2, n_estimators=100;, score=0.800 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 2/5] END criterion=entropy, max_features=log2, n_estimators=100;, score=0.842 total time=   0.4s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 3/5] END criterion=entropy, max_features=log2, n_estimators=100;, score=0.810 total time=   0.4s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 4/5] END criterion=entropy, max_features=log2, n_estimators=100;, score=0.900 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [CV 5/5] END criterion=entropy, max_features=log2, n_estimators=100;, score=0.947 total time=   0.3s
# C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81248751 0.85810653 0.83405384 0.83944684
#         nan        nan 0.83413685 0.86087912 0.80364774 0.8597995 ]
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              scoring='f1', verbose=3)

# %%
re=grid.cv_results_ 
grid_predictions=grid.predict(X_test) 
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(cm)
# Out:
# [[ 0 85]
#  [ 0 49]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        85
#            1       0.37      1.00      0.54        49
#
#     accuracy                           0.37       134
#    macro avg       0.18      0.50      0.27       134
# weighted avg       0.13      0.37      0.20       134

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.176301      0.341253         0.000000        0.000000
# 1        0.002203      0.000400         0.000000        0.000000
# 2        0.436672      0.627469         0.225810        0.337893
# 3        0.709974      0.120222         0.038431        0.008489
# 4        0.060053      0.019703         0.037025        0.018046
# 5        0.505450      0.085669         0.033423        0.003265
# 6        0.001200      0.000400         0.000000        0.000000
# 7        0.001400      0.000490         0.000000        0.000000
# 8        0.048125      0.008904         0.023815        0.006149
# 9        0.413027      0.045868         0.030105        0.001505
# 10       0.046320      0.006415         0.021414        0.005280
# 11       0.404004      0.032104         0.034623        0.004968
#
#    param_criterion param_max_features  param_n_estimators  \
# 0             gini               auto                  10
# 1             gini               auto                 100
# 2             gini               sqrt                  10
# 3             gini               sqrt                 100
# 4             gini               log2                  10
# 5             gini               log2                 100
# 6          entropy               auto                  10
# 7          entropy               auto                 100
# 8          entropy               sqrt                  10
# 9          entropy               sqrt                 100
# 10         entropy               log2                  10
# 11         entropy               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 1   {'criterion': 'gini', 'max_features': 'auto', ...                NaN
# 2   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.727273
# 3   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.764706
# 4   {'criterion': 'gini', 'max_features': 'log2', ...           0.727273
# 5   {'criterion': 'gini', 'max_features': 'log2', ...           0.727273
# 6   {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 7   {'criterion': 'entropy', 'max_features': 'auto...                NaN
# 8   {'criterion': 'entropy', 'max_features': 'sqrt...           0.727273
# 9   {'criterion': 'entropy', 'max_features': 'sqrt...           0.800000
# 10  {'criterion': 'entropy', 'max_features': 'log2...           0.750000
# 11  {'criterion': 'entropy', 'max_features': 'log2...           0.800000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.820513           0.809524           0.871795
# 3            0.842105           0.809524           0.926829
# 4            0.871795           0.780488           0.871795
# 5            0.842105           0.780488           0.900000
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.810811           0.809524           0.900000
# 9            0.871795           0.809524           0.900000
# 10           0.756757           0.780488           0.842105
# 11           0.842105           0.809524           0.900000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                9
# 1                 NaN              NaN             NaN                9
# 2            0.833333         0.812488        0.047511                7
# 3            0.947368         0.858107        0.069326                3
# 4            0.918919         0.834054        0.069746                6
# 5            0.947368         0.839447        0.079221                4
# 6                 NaN              NaN             NaN                9
# 7                 NaN              NaN             NaN                9
# 8            0.923077         0.834137        0.070453                5
# 9            0.923077         0.860879        0.048707                1
# 10           0.888889         0.803648        0.053588                8
# 11           0.947368         0.859799        0.056038                2
