# %%
import os
from autogen import ConversableAgent

# 🔑 API Key
os.environ["GEMINI_API_KEY"] = "AIzaSyALi9-EbQbGpVM4UKTt6969cAcRLeqM03U"

# ⚙️ Config
llm_config = {
    "config_list": [
        {
            "model": "gemini-2.5-flash",
            "api_key": os.environ["GEMINI_API_KEY"],
            "api_type": "google"
        }
    ],
    "max_tokens": 80
}

# 🏭 Production Manager
production_manager = ConversableAgent(
    name="production_manager",
    system_message="""
You are a production manager.
Focus on speed and meeting targets.
Reply in 1-2 short lines.
""",
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# 🧪 Quality Manager
quality_manager = ConversableAgent(
    name="quality_manager",
    system_message="""
You are a quality manager.
Focus on product quality and standards.
Reply in 1-2 short lines.
""",
    llm_config=llm_config,
    human_input_mode="NEVER"
)

# 🚀 Start Conversation
chat_result = production_manager.initiate_chat(
    quality_manager,
    message="Production is delayed. Can we skip some quality checks to speed up?"
)

print(chat_result)
# Out:
# production_manager (to quality_manager):
#
# Production is delayed. Can we skip some quality checks to speed up?
#
# --------------------------------------------------------------------------------
# quality_manager (to production_manager):
#
# No
#
# --------------------------------------------------------------------------------
# production_manager (to quality_manager):
#
# Understood
#
# --------------------------------------------------------------------------------
# quality_manager (to production_manager):
#
# Maintaining product quality and adherence to standards is non
#
# --------------------------------------------------------------------------------
# production_manager (to quality_manager):
#
# Understood.
#
# --------------------------------------------------------------------------------
# quality_manager (to production_manager):
#
# Maintaining product quality and adherence to standards is non-negotiable, even with production challenges.
#
# ...
