# %%
from subfields import subfieldsInAI

# %%
subfieldsInAI.subfields()
# Out:
# subfields in AI are:
# machine learning
# neural network
# vision
# Robotics
# speech processing
# Natural language processing

# %%
from marriage import eligibilityformarriage

# %%
eligibilityformarriage.elegible()
# Out:
# your gender(male,female): male
# your age 22
# eligible
# 'eligible'

# %%
from oddeven import oddeven

# %%
oddeven.oddeven()
# Out:
# enter the number: 11
# 11 is odd number
# 'num is odd number'

# %%
from percentage import findpercent

# %%
findpercent.Percentage()
# Out:
# subject 1= 11
# Subject 2= 55
# subject 3= 55
# subject 4= 54
# subject 5= 52
# total = 227
# the percentage= 45.4

# %%
from tri import triangle

# %%
triangle.triangle()
# Out:
# height: 5
# breadth: 25
# area of triangle 62.5
# height1: 22
# height2: 52
# breadth2: 22
# perimeter of the triangle: 96
