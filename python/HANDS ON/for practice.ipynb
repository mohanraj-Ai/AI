# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 52

# %%
if(age==18):
    print("Adult")

# %%
age=int(input("Enter the age:"))
if(age<18):
    print("Children")
else:
    print("Adult")
# Out:
# Enter the age: 54
# Adult

# %%
age=int(input("Enter the age:"))
if(age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("citizen")
else:
    print("Senior Citizen")
# Out:
# Enter the age: 45
# citizen
