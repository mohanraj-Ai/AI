# %%
Question 1:

Task: Implement a FAISS-based Retrieval System that fetches the most relevant document for query-based retrieval

# %%
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Anaconda3\envs\langchain\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
documents = [
    "Artificial Intelligence is transforming industries.",
    "Machine Learning is a subset of AI.",
    "FAISS is used for similarity search.",
    "Deep Learning uses neural networks.",
    "Natural Language Processing helps computers understand text."
]

# %%
document_embeddings = model.encode(documents)

# %%
dimension = document_embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

index.add(np.array(document_embeddings))

# %%
def retrieve_document(query, top_k=1):
    
    query_embedding = model.encode([query])
    
    distances, indices = index.search(
        np.array(query_embedding),
        top_k
    )
    
    results = []
    
    for idx in indices[0]:
        results.append(documents[idx])
    
    return results

# %%
query = "What is similarity search?"

results = retrieve_document(query)

print("Query:", query)

print("\nRetrieved Documents:")

for doc in results:
    print("-", doc)
# Out:
# Query: What is similarity search?
#
# Retrieved Documents:
# - FAISS is used for similarity search.

# %%
Question 2:

Task: Use Gemini API to generate answers based on retrieved knowledge.

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyAx4dV6WeTsHXzileVzd0vSVGtwEKQ6LIg")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
context = """
cricket is a sports in india supported by many peoples. England is the orgin of cricket
"""

# %%
query = "which is the orgin of cricket?"

# %%
response = model.generate_content(f"Use the following context to answer: {context}\n\n{query}")

# %%
print("Gemini AI Response:", response.text)
# Out:
# Gemini AI Response: England is the origin of cricket.

# %%
Question 3:

Task: Implement FAISS with a hybrid (dense & sparse) vector search for improving information retrieval.

# %%
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# Load embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Sample knowledge base
docs = [
    "FAISS supports fast vector similarity search.",
    "Hybrid search combines dense embeddings with keyword-based retrieval.",
    "Efficient vector search improves information retrieval."
]

# Compute dense embeddings
embeddings = np.array([model.encode(doc) for doc in docs], dtype=np.float32)

# Create FAISS index
index = faiss.IndexFlatIP(embeddings.shape[1])  # Inner Product Search
index.add(embeddings)

# User Query
query = "What is hybrid search?"
query_embedding = np.array([model.encode(query)], dtype=np.float32)

# Retrieve the best document
D, I = index.search(query_embedding, k=1)
retrieved_doc = docs[I[0][0]]

print("Retrieved Document:", retrieved_doc)
# Out:
# Retrieved Document: Hybrid search combines dense embeddings with keyword-based retrieval.

# %%
Question 4:

Task: Implement a Multi-Turn Conversational Chatbot using Gemini API that maintains context across multiple user interactions.

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyAx4dV6WeTsHXzileVzd0vSVGtwEKQ6LIg")

model = genai.GenerativeModel("gemini-2.5-flash")

chat = model.start_chat(history=[])

print("Multi-Turn Chatbot Started!")
print("Type 'exit' to stop.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chat Ended.")
        break

    response = chat.send_message(user_input)

    print("Bot:", response.text)
# Out:
# Multi-Turn Chatbot Started!
# Type 'exit' to stop.
# C:\Users\User\AppData\Local\Temp\ipykernel_5764\1326817877.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# You:  hi
# Bot: Hello! How can I help you today?
# You:  give me motivation
# Bot: Alright, let's ignite that fire within you! You asked for motivation, and guess what? It's already there, simmering, waiting to burst forth.
#
# Here's why you are capable of amazing things:
#
# 1.  **You are stronger than you think.** Look back at everything you've overcome, every challenge you've met. You have a track record of resilience. That power is still within you, ready to be called upon.
#
# 2.  **Your dreams and goals are valid.** Don't let anyone, especially your own doubts, tell you otherwise. What is it that truly excites you? What change do you want to see? What vision whispers to you? Hold onto that with everything you've got.
#
# 3.  **Start where you are. Use what you have. Do what you can.** You don't need perfect conditions, all the answers, or a sudden burst of lightning inspiration. Just take that first small step. Break it down. One email. One page. One conversation. One push-up. Momentum builds from movement, not from waiting.
#
# 4.  **Mistakes are not failures; they are lessons.** Every "setback" is an opportunity to learn, adjust, and come back stronger. It means you're trying. It means you're pushing boundaries. That's commendable!
#
# 5.  **Your time is now.** Stop waiting for "someday." Stop waiting for permission. The only permission you need is your own. The present moment is the only one you truly have to make a difference, to create, to grow.
#
# 6.  **The world needs what you have to offer.** Your unique perspective, your talents, your energy, your ideas – they are valuable. Don't hold back. Share your light.
#
# **So, take a deep breath.** Feel that energy building? That's your power. That's your will.
#
# **You are capable. You are worthy. You are ready.**
#
# Now, go out there and make something happen. The world is waiting for you. **Go get 'em!**
# You:  exit
# Chat Ended.

# %%
Question 5:

Task: Implement a FAISS-based retrieval-augmented generation (RAG) system using the Gemini API, 
where retrieved documents are used as context to generate more accurate and relevant responses.

# %%
import google.generativeai as genai
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# -------------------------------
# Configure Gemini API
# -------------------------------
genai.configure(api_key="AIzaSyAx4dV6WeTsHXzileVzd0vSVGtwEKQ6LIg")

# Load Gemini Model
gemini_model = genai.GenerativeModel("gemini-2.5-flash")

# -------------------------------
# Sample Documents
# -------------------------------
documents = [
    "Artificial Intelligence is the simulation of human intelligence by machines.",
    
    "Machine Learning is a subset of AI that enables systems to learn from data.",
    
    "Deep Learning uses neural networks with multiple layers.",
    
    "FAISS is a library developed by Facebook for efficient similarity search.",
    
    "Retrieval-Augmented Generation combines retrieval with text generation."
]

# -------------------------------
# Load Embedding Model
# -------------------------------
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# Convert documents into embeddings
document_embeddings = embedding_model.encode(documents)

# Convert to float32 (required for FAISS)
document_embeddings = np.array(document_embeddings).astype("float32")

# -------------------------------
# Create FAISS Index
# -------------------------------
dimension = document_embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

# Add document embeddings to FAISS
index.add(document_embeddings)

print("FAISS Index Created Successfully!")

# -------------------------------
# RAG Function
# -------------------------------
def rag_chatbot(query, top_k=2):

    # Convert query into embedding
    query_embedding = embedding_model.encode([query])

    query_embedding = np.array(query_embedding).astype("float32")

    # Search similar documents
    distances, indices = index.search(query_embedding, top_k)

    # Retrieve relevant documents
    retrieved_docs = [documents[i] for i in indices[0]]

    # Create context
    context = "\n".join(retrieved_docs)

    # Create final prompt
    prompt = f"""
    Use the following context to answer the question.

    Context:
    {context}

    Question:
    {query}
    """

    # Generate response using Gemini
    response = gemini_model.generate_content(prompt)

    return response.text


print("\nRAG Chatbot Started!")
print("Type 'exit' to stop.\n")

while True:

    user_query = input("You: ")

    if user_query.lower() == "exit":
        print("Chatbot Ended.")
        break

    answer = rag_chatbot(user_query)

    print("\nBot:", answer)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11224\2680851090.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# FAISS Index Created Successfully!
#
# RAG Chatbot Started!
# Type 'exit' to stop.
# You:  HI
# Bot: Hi there!
#
# The context provided discusses Retrieval-Augmented Generation and Machine Learning, but your question is a greeting. Is there something specific you'd like to know about those topics, or a different question I can help you with?
# You:  WHAT IS MACHINE LEARNING
# Bot: Machine Learning is a subset of AI that enables systems to learn from data.
# You:  EXIT
# Chatbot Ended.
