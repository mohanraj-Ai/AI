# %%
import joblib

scaler = joblib.load("scaler.pkl")
print(type(scaler))
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>

# %%
print(hasattr(scaler, "mean_"), hasattr(scaler, "scale_"))
print("Features:", scaler.n_features_in_)
# Out:
# True True
# Features: 5

# %%
import joblib

model = joblib.load("final_model_rf.sav")   # or .joblib
scaler = joblib.load("scaler.pkl")

# %%
X_new = [[2.5, 4, 24, 30,1]]
X_new_scaled = scaler.transform(X_new)
prediction = model.predict(X_new_scaled)
# Out:
# C:\Anaconda3\envs\aimj\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Anaconda3\envs\aimj\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([19.70434297])

# %%
from sklearn.pipeline import Pipeline
import joblib

pipeline = Pipeline([
    ("scaler", scaler),
    ("model", model)
])

joblib.dump(pipeline, "fuel_pipeline.joblib", compress=3)
# Out:
# ['fuel_pipeline.joblib']
