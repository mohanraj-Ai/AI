# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacementdata.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
import scipy.stats as stats
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.6719700864663097, pvalue=0.5110602818995302)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model = ols('salary ~ hsc_b	+ ssc_b', data=dataset).fit()

# %%
anova_table = sm.stats.anova_lm(model, typ=2)

# %%
print(anova_table)
# Out:
#                 sum_sq     df         F    PR(>F)
# hsc_b     7.182091e+08    1.0  0.029739  0.863249
# ssc_b     6.170513e+09    1.0  0.255499  0.613754
# Residual  5.119973e+12  212.0       NaN       NaN

# %%
plant_heights = {
    'Treatment': ['A', 'A', 'A', 'A', 'A', 'A',
                  'B', 'B', 'B', 'B', 'B', 'B',
                  'C', 'C', 'C', 'C', 'C', 'C'],
    'Time': ['Early', 'Early', 'Early', 'Late', 'Late', 'Late',
             'Early', 'Early', 'Early', 'Late', 'Late', 'Late',
             'Early', 'Early', 'Early', 'Late', 'Late', 'Late'],
    'Height': [25, 28, 23, 27, 26, 24,
               20, 22, 19, 21, 24, 22,
               18, 20, 17, 19, 21, 20]
}

# %%
df = pd.DataFrame(plant_heights)

# %%
df
# Out:
#    Treatment   Time  Height
# 0          A  Early      25
# 1          A  Early      28
# 2          A  Early      23
# 3          A   Late      27
# 4          A   Late      26
# 5          A   Late      24
# 6          B  Early      20
# 7          B  Early      22
# 8          B  Early      19
# 9          B   Late      21
# 10         B   Late      24
# 11         B   Late      22
# 12         C  Early      18
# 13         C  Early      20
# 14         C  Early      17
# 15         C   Late      19
# 16         C   Late      21
# 17         C   Late      20

# %%
model = ols('Height ~ C(Treatment) + C(Time) + C(Treatment):C(Time)', data=df).fit()

# %%
anova_table = sm.stats.anova_lm(model, typ=2) = sm.stats.anova_lm(model, typ=2)

# %%
anova_table = sm.stats.anova_lm(model, typ=2)

# %%
print(anova_table)
# Out:
#                           sum_sq    df      F    PR(>F)
# C(Treatment)          124.333333   2.0  22.38  0.000089
# C(Time)                 8.000000   1.0   2.88  0.115447
# C(Treatment):C(Time)    2.333333   2.0   0.42  0.666342
# Residual               33.333333  12.0    NaN       NaN
