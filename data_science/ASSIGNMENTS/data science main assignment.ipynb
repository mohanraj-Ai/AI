# %%
#1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset=pd.read_csv("placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from univariaten import univariate

# %%
quan,qual=univariate.quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive=univariate.univariate(dataset, quan)

# %%
descriptive
# Out:
#            sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean       108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median     108.0       67.0       65.0       66.0       71.0       62.0
# Mode           1       62.0       63.0       65.0       60.0       56.7
# Q1:25%      54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%     108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%     161.5       75.7       73.0       72.0       83.5     66.255
# 99        212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100       215       89.4      91.15       88.5       98.0      77.89
# IQR        107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule    160.5      22.65      18.15       16.5      35.25     12.465
# Lesser    -106.0      37.95      42.75       44.5      24.75      45.48
# Greater    322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
lesser,greater=univariate.lesserGreater(quan,descriptive)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
univariate.outlierfix(dataset, descriptive, lesser, greater)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          215 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#Explanation for replacing the NUN values.
There is 4 way to replace the missing values.
1.replace the missing value with central tendency(mean,median,mode)
    In this dataset salary data have a missing values. if it is replace by central tendency, it will consider as student recieve a salary.
    In this case in placement data, not placed students are not getting salary. So if we fill some values, the dataset will be filled with 
    wrong dataes.
2.Delete entire rows.
    In the salary data 148 nun values in 215 rows.So we cannot delete entire row. It like a delete half of a dataset.
3.Create a model to predict missing values.
    In this case create model in unnessesary way to fill the nun values.
4.Respective to the problem, have to replace the missing values.
    i thought this is good way to fill the nun values. Because i filled the NUN values with '0', which is not change the nature of the dataset.

# %%
# 2.How many of them are not placed?

# %%
dataset["status"].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
#.Explanation for the not placed students counts.
    here i am using value_count() function to find out the not placed students counts in the dataset(status)

# %%
#3.)Find the reason for non placement from the dataset?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='status',data=dataset)
plt.title('not plcaed data')
plt.xlabel('status')
plt.ylabel('ssc_p')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='status',data=dataset)
plt.title('not plcaed data')
plt.xlabel('status')
plt.ylabel('hsc_p')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='status',data=dataset)
plt.title('not plcaed data')
plt.xlabel('status')
plt.ylabel('degree_p')
plt.tight_layout()
plt.show()

# %%
#3.Explanation: reason for non placement from the dataset
    here i using countplot based on the status data(for placed and not placed) for various dataes like ssc p,hsc p, degree p.
    i saw the result, if the students are getting low marks in ssc p, hsc_p,degree p , they will not placed in the placement.

# %%
#4.What kind of relation between salary and mba_p

# %%
corr=dataset['salary'].corr(dataset['mba_p'])

# %%
print(corr)
# Out:
# 0.13408358486003136

# %%
#4.Explanation:relation between salary and mba_p
    The relation between the salary and mba_p is postive correlation, because r value is postive. Also it is a lower degree postive correlation.

# %%
#5.Which specialization is getting minimum salary

# %%
sns.barplot(x="specialisation",y="salary",data=dataset,)
# Out:
# <Axes: xlabel='specialisation', ylabel='salary'>

# %%
#5.Explanation: Which specialization is getting minimum salary
 Based on the barchart Mkt&HR specialization is getting minimum salary.

# %%
#6.How many of them getting above 500000 salary?

# %%
count=(dataset["salary"]>50000).sum()
print("The number of student getting salary above 50000 ",count)
# Out:
# The number of student getting salary above 50000  148

# %%
#6.Examplanation: I am using sum function to find out the number of persons geting above 50000 salary.

# %%
#7.Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
# 7.Examplanation:
    p value of the etestp and mbap is 4.672547689133573e-21
    here is p <0.05, so reject null hypothesis and accept alternative hypothesis.
    H1- There is  significant difference the etest and mbap

# %%
#8.Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%
#.(Makedecision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
scitech=dataset[dataset['degree_t']=='Sci&Tech']['salary']
mkthr=dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(scitech,mkthr)
# Out:
# TtestResult(statistic=2.3852430796563096, pvalue=0.018299948650088643, df=152.0)

# %%
#8.Examplanation:
    Here i am using T-Test, to find the similarity between the degree_t(sci&Tech) and specialisation(Mkt&HR) with respect to salary.
    if the pvalue is <0.05, the pvalues are good.Also result is considered statiscally significant. 
    Here pvalue=0.018299948650088643,so it below the 0.05. The result is considered statiscally significant.
    based on pvalue reject the Null hypothesis and accept the Alternative hypothesis.

# %%
#9.Convert the normal distribution to standard normal distribution for salary column

# %%
def stdNBgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    
    values=[i for i in dataset]
    
    z_score=[((j-mean)/std) for j in values]
    
    sns.displot(z_score,kde=True)
    
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["salary"])

# %%
# 9.Examplanation: standard normal distribution for salary column
        based on the Std normal distribution graph, the salary column is not normally distributed.

# %%
#10.What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    sample=dataset
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    dist=norm(sample_mean,sample_std) 
    values= [value for value in range(startrange,endrange)]
    probabilities= [dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}". format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\MohanRaj\AppData\Local\Temp\ipykernel_2544\3196135723.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=191125.581, Standard Deviation=136516.433
# The area between range(700000,900000):9.656554457612299e-05
# 9.656554457612299e-05

# %%
#10.Examplanation:probability Density Function of the salary range from 700000 to 900000
    i am using created function to distplot salary column. At that salary column, the probability to get salary from  700000 to 900000.
    The mean value of the salary: 191125.581
    Standard Deviation of the salary=136516.433
    The area between range(700000,900000): 0
    it shows the probability of student getting salary range from 700000 to 900000 is 0%

# %%
#11.Test the similarity between the degree_t(Sci&Tech)with respect to
etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
from scipy.stats import ttest_ind
etest=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mba=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_ind(etest,mba)
# Out:
# TtestResult(statistic=4.532000225151251, pvalue=1.4289217003775636e-05, df=116.0)

# %%
#11.Examplanation: Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%
    
    Here i am using T-Test, to find the similarity between the degree_t(sci&Tech) )with respect to etest_p and mba_p.
    if the pvalue is <0.05, the pvalues are good.Also result is considered statiscally significant. 
    Here pvalue=1.4289217003775636e-05,so it below the 0.05. The result is considered statiscally significant.
    Based on pvalue reject the Null hypothesis and accept the Alternative hypothesis.

# %%
#12.Which parameter is highly correlated with salary

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327 -0.019367
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.605710
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.486374
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.464159
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.191970
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.134084
# salary   -0.019367  0.605710  0.486374  0.464159  0.191970  0.134084  1.000000

# %%
#12.Examplanation:  parameter is highly correlated with salary

    i am using corr() inbuild function to find the correlation between the columns.
    Based on the output, salary is highly correlated with ssc_p following by hsc_p

# %%
# 13.plot any useful graph and explain it.

# %%
sns.pairplot(dataset)

# %%
#13.Examplanation: 
    i am using pairplot to explain how columns are correlated with the salary.
    most of students are getting salary between 200000 to 300000.some students are getting 400000.Here 0 values indicates not placed students.
    salary vs sscp : stdudent with high ssc marks will get more salary.strong postive correlation.
    salary vs hscp : here also students with high hsc marks will get better salary.
    salary vs degreep : salary and degreep are with postive correlation. 
    salary vs etestp: some averge score students get good salary.etest may help in getting placed.
    salary vs mbap : positive correlation and also mbap may help for getting placed.
