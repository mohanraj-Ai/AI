# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 🔐 Load API key (Make sure .env has GOOGLE_API_KEY)
load_dotenv(dotenv_path=".env")

# 🔸 Initialize Gemini 2.5 Flash
# You can also use "gemini-2.0-flash" or "gemini-2.5-pro" from your list
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0
)

# 🔸 Create Chat Prompt Template (Modern Standard)
prompt = ChatPromptTemplate.from_template("Answer clearly: {question}")

# 🔸 Create the Chain using LCEL (Pipe syntax)
# This replaces LLMChain and handles output parsing automatically
chain = prompt | llm | StrOutputParser()

# 🚀 Run a query
query = "What is LangGraph in LangChain?"
response = chain.invoke({"question": query})

# 🖨️ Output
print("\nUser Question:", query)
print("\nLLM Answer:", response)
# Out:
# User Question: What is LangGraph in LangChain?
#
# LLM Answer: **LangGraph is an extension of the LangChain framework designed specifically for building stateful, multi-actor applications with cyclical graphs.**
#
# In simpler terms:
#
# 1.  **LangChain:** Provides the fundamental building blocks for creating LLM-powered applications (like LLMs, prompt templates, tools, memory, and simple sequential "chains"). It helps you connect these components in a pipeline.
#
# 2.  **LangGraph:** Builds upon these LangChain primitives but introduces a more powerful way to **orchestrate complex workflows** that go beyond simple linear chains. It allows you to define an application as a **graph**, where:
#     *   **Nodes** are individual steps or actions (e.g., calling an LLM, using a tool, performing a database lookup, asking for human input).
#     *   **Edges** define the transitions between these nodes, often based on the output or state from the previous node.
# ...
