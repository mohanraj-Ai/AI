# %%
import pandas as pd

# %%
from nsepy import get_history as gh
import datetime as dt

# %%
start = dt.datetime(2024,1,1)
end = dt.datetime(2024,7,28)
stk_data = gh(symbol='TATACOFFEE',start=start,end=end)
# Out:
# Exception in thread Thread-3 (get_history):
# Traceback (most recent call last):
#   File "C:\Anaconda3\envs\aimj\Lib\site-packages\urllib3\connectionpool.py", line 464, in _make_request
#     self._validate_conn(conn)
#   File "C:\Anaconda3\envs\aimj\Lib\site-packages\urllib3\connectionpool.py", line 1093, in _validate_conn
#     conn.connect()
#   File "C:\Anaconda3\envs\aimj\Lib\site-packages\urllib3\connection.py", line 790, in connect
#     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\envs\aimj\Lib\site-packages\urllib3\connection.py", line 969, in _ssl_wrap_socket_and_match_hostname
#     ssl_sock = ssl_wrap_socket(
#                ^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\envs\aimj\Lib\site-packages\urllib3\util\ssl_.py", line 480, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
# ...
