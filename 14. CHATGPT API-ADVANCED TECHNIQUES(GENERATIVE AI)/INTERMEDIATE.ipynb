# %%
import google.generativeai as genai

# 1. Setup
genai.configure(api_key="AIzaSyApwfKocmlFdobH2gyxknzwcSiz7WQGe9o") 

# 2. Personality
# For your Service Advisor, try entering: 
# "You are an expert automotive service advisor specializing in predictive maintenance."
system_instruction = input("What type of chatbot would you like to create?\n")

# 3. Initialize with the 2026 Stable Model
try:
    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash", 
        system_instruction=system_instruction
    )

    chat_session = model.start_chat(history=[])
    print("\n--- Assistant is Online! (Type 'quit' to stop) ---\n")

    while True:
        user_input = input("You: ")
        if user_input.lower() in ["quit", "exit", "bye"]:
            break

        response = chat_session.send_message(user_input)
        print(f"\nAssistant: {response.text}\n")

except Exception as e:
    print(f"\n[Error]: {e}")
# Out:
# What type of chatbot would you like to create?
#  service advis
# --- Assistant is Online! (Type 'quit' to stop) ---
# You:  car
# Assistant: Okay, what about your car? Are you looking to schedule service, describe a problem, or ask a general question?
# You:  maintainance
# Assistant: Okay, "maintenance" covers a lot! To help me understand what you're looking for, could you tell me a bit more?
#
# Are you looking for:
#
# *   **General information** about common car maintenance tasks?
# *   What **maintenance is due** for your specific car (based on mileage or time)?
# *   Information about a **specific service** like an oil change, tire rotation, or brake check?
# *   To **schedule** a maintenance appointment?
# *   Or are you experiencing a **particular issue** that you think might be related to maintenance?
#
# Also, if you can provide your **car's make, model, year, and current mileage**, that will help me give you more accurate advice!
# You:  swift 2012 95555
# ...
